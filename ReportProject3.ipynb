# %%
Course-End Project: Sales Analysis

# %% [markdown]
# # Data Visualization

# %%
# Define custom color palette
custom_palette = ["#6497b1", "#03396c", "#005b96", "#011f4b"]  # Add your desired colors here

# State-wise sales analysis for different groups
plt.figure(figsize=(12, 6))
sns.barplot(x='State', y='Sales', hue='Group', data=df, palette=custom_palette)
plt.title('State-wise Sales Analysis for Different Groups')
plt.xlabel('State')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.legend(title='Group')
plt.tight_layout()
plt.show()

# %%
# Group-wise sales analysis across different states 
custom_palette = ["#03045e", "#023e8a", "#0077b6", "#0096c7", "#00b4d8", "#48cae4", "#90e0ef"]

plt.figure(figsize=(12, 6))
sns.barplot(x='Group', y='Sales', hue='State', data=df, palette=custom_palette)
plt.title('Group-wise Sales Analysis Across Different States')
plt.xlabel('Group')
plt.ylabel('Sales')
plt.xticks(rotation=45)
plt.legend(title='State')
plt.tight_layout()
plt.show()

# %%
# Group the data by 'Time' and sum 'Sales'
time_sales = df.groupby('Time')['Sales'].sum().reset_index()

# Sort the results to identify highest and lowest sales times
time_sales_sorted = time_sales.sort_values(by='Sales', ascending=False)

custom_palette = ["#283044", "#78a1bb", "#D5DED7"]

# Visualization
plt.figure(figsize=(10, 6))
sns.barplot(data=time_sales_sorted, x='Time', y='Sales', order=time_sales_sorted['Time'], palette=custom_palette)
plt.title('Sales by Time of the Day')
plt.xlabel('Time of the Day')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# # Answering these questions
# ### 1) Determine the states that are generating the highest revenues

# %% [markdown]
# The state 'VIC' generates the highest sales, with total sales of $105,565,000.

# %% [markdown]
# ### 2) Formulate programs for states with lower revenues.

# %% [markdown]
# The states with lower revenues are 'NT' and 'WA'.

# %% [markdown]
# ### 3) Recommendations to the Head of Sales and Marketing

# %% [markdown]
# A. Tailored sales programs: Formulating initiatives to address specific challenges and opportunities in each state, such as targeted marketing campaigns, promotions, discounts, product enhancements, customer service improvements, and distribution channel expansion.
#
# B. Market research and customer feedback: Utilizing these sources to gain insights and develop effective strategies for increasing sales.
#
# C. Sales insights: Men's clothing products generate the highest sales, indicating a strong demand. Seniors generate the lowest sales, suggesting room for improvement and targeted marketing to cater to their needs. Highest sales occur in the morning, while the lowest occur in the evening, informing marketing activities, promotions, and staffing schedules to maximize sales during peak hours.
#
#
# Team 3 members :
# Asma Alyousef
# Rofidah Kamal Hanbzaza
# Amal Abdullah
